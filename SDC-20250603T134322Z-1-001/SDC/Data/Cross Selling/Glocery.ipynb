# %%
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os

# %%
path_Data = "/content/drive/MyDrive/SDC/Data/Cross Selling/"
checkPath = os.path.isdir(path_Data)
checkFile = os.path.isfile(path_Data + "grocery_dataset.txt")
print("The path and file are valid or not :", checkPath, checkFile)
# Out:
# The path and file are valid or not : True True

# %%
grocery_items = set()
with open(path_Data + "grocery_dataset.txt") as f:
    reader = csv.reader(f, delimiter=",")
    for i, line in enumerate(reader):
        grocery_items.update(line)

# %%
display("-".join(grocery_items))
print(len(grocery_items))
# Out:
# 'dishes-prosecco-condensed milk-frozen fruits-grapes-flour-waffles-oil-frozen potato products-flower (seeds)-dog food-rubbing alcohol-roll products -misc. beverages-baby cosmetics-sausage-abrasive cleaner-honey-chocolate-butter milk-processed cheese-preservation products-hard cheese-pip fruit-newspapers-shopping bags-canned beer-cat food-frozen chicken-light bulbs-jam-bathroom cleaner-kitchen towels-nut snack-softener-hair spray-popcorn-sugar-napkins-hamburger meat-cooking chocolate-vinegar-male cosmetics-domestic eggs-cleaner-salty snack-meat spreads-candles-white wine-female sanitary products-cereals-other vegetables-cookware-organic products-berries-cake bar-flower soil/fertilizer-yogurt-dental care-pasta-instant coffee-margarine-hygiene articles-dish cleaner-organic sausage-sparkling wine-sweet spreads-snack products-seasonal products-canned fish-bottled water-liquor (appetizer)-sauces-decalcifier-tropical fruit-fish-frozen meals-fruit/vegetable juice-toilet cleaner-specialty vegetables-cream cheese -specialty cheese-skin care-long life bakery product-tidbits-ketchup-brandy-cling film/bags-coffee-beverages-whipped/sour cream-frankfurter-candy-beef-canned fruit-soap-mayonnaise-ham-frozen vegetables-house keeping products-sound storage medium-spread cheese-rum-root vegetables-butter-citrus fruit-ice cream-specialty bar-liqueur-photo/film-UHT-milk-nuts/prunes-mustard-onions-turkey-cocoa drinks-syrup-pet care-rice-liver loaf-pot plants-ready soups-frozen fish-soups-pudding powder-soft cheese-cream-spices-herbs-frozen dessert-finished products-soda-artif. sweetener-rolls/buns-bags-whisky-liquor-red/blush wine-meat-pickled vegetables-curd cheese-detergent-tea-chocolate marshmallow-canned vegetables-make up remover-chewing gum-salt-salad dressing-kitchen utensil-baby food-sliced cheese-bottled beer-packaged fruit/vegetables-whole milk-dessert-zwieback-potato products-specialty chocolate-baking powder-brown bread-pork-curd-white bread-semi-finished bread-chicken-Instant food products-pastry-specialty fat'
# 169

# %%
output_list = list()
with open(path_Data + "grocery_dataset.txt") as f:
    reader = csv.reader(f, delimiter=",")
    for i, line in enumerate(reader):
        row_val = {item:0 for item in grocery_items}
        row_val.update({item:1 for item in line})
        output_list.append(row_val)

# %%
print(len(output_list), len(output_list[0]))
print(output_list[:5])
# Out:
# 9835 169
# [{'dishes': 0, 'prosecco': 0, 'condensed milk': 0, 'frozen fruits': 0, 'grapes': 0, 'flour': 0, 'waffles': 0, 'oil': 0, 'frozen potato products': 0, 'flower (seeds)': 0, 'dog food': 0, 'rubbing alcohol': 0, 'roll products ': 0, 'misc. beverages': 0, 'baby cosmetics': 0, 'sausage': 0, 'abrasive cleaner': 0, 'honey': 0, 'chocolate': 0, 'butter milk': 0, 'processed cheese': 0, 'preservation products': 0, 'hard cheese': 0, 'pip fruit': 0, 'newspapers': 0, 'shopping bags': 0, 'canned beer': 0, 'cat food': 0, 'frozen chicken': 0, 'light bulbs': 0, 'jam': 0, 'bathroom cleaner': 0, 'kitchen towels': 0, 'nut snack': 0, 'softener': 0, 'hair spray': 0, 'popcorn': 0, 'sugar': 0, 'napkins': 0, 'hamburger meat': 0, 'cooking chocolate': 0, 'vinegar': 0, 'male cosmetics': 0, 'domestic eggs': 0, 'cleaner': 0, 'salty snack': 0, 'meat spreads': 0, 'candles': 0, 'white wine': 0, 'female sanitary products': 0, 'cereals': 0, 'other vegetables': 0, 'cookware': 0, 'organic products': 0, 'berries': 0, 'cake bar': 0, 'flower soil/fertilizer': 0, 'yogurt': 0, 'dental care': 0, 'pasta': 0, 'instant coffee': 0, 'margarine': 1, 'hygiene articles': 0, 'dish cleaner': 0, 'organic sausage': 0, 'sparkling wine': 0, 'sweet spreads': 0, 'snack products': 0, 'seasonal products': 0, 'canned fish': 0, 'bottled water': 0, 'liquor (appetizer)': 0, 'sauces': 0, 'decalcifier': 0, 'tropical fruit': 0, 'fish': 0, 'frozen meals': 0, 'fruit/vegetable juice': 0, 'toilet cleaner': 0, 'specialty vegetables': 0, 'cream cheese ': 0, 'specialty cheese': 0, 'skin care': 0, 'long life bakery product': 0, 'tidbits': 0, 'ketchup': 0, 'brandy': 0, 'cling film/bags': 0, 'coffee': 0, 'beverages': 0, 'whipped/sour cream': 0, 'frankfurter': 0, 'candy': 0, 'beef': 0, 'canned fruit': 0, 'soap': 0, 'mayonnaise': 0, 'ham': 0, 'frozen vegetables': 0, 'house keeping products': 0, 'sound storage medium': 0, 'spread cheese': 0, 'rum': 0, 'root vegetables': 0, 'butter': 0, 'citrus fruit': 1, 'ice cream': 0, 'specialty bar': 0, 'liqueur': 0, 'photo/film': 0, 'UHT-milk': 0, 'nuts/prunes': 0, 'mustard': 0, 'onions': 0, 'turkey': 0, 'cocoa drinks': 0, 'syrup': 0, 'pet care': 0, 'rice': 0, 'liver loaf': 0, 'pot plants': 0, 'ready soups': 1, 'frozen fish': 0, 'soups': 0, 'pudding powder': 0, 'soft cheese': 0, 'cream': 0, 'spices': 0, 'herbs': 0, 'frozen dessert': 0, 'finished products': 0, 'soda': 0, 'artif. sweetener': 0, 'rolls/buns': 0, 'bags': 0, 'whisky': 0, 'liquor': 0, 'red/blush wine': 0, 'meat': 0, 'pickled vegetables': 0, 'curd cheese': 0, 'detergent': 0, 'tea': 0, 'chocolate marshmallow': 0, 'canned vegetables': 0, 'make up remover': 0, 'chewing gum': 0, 'salt': 0, 'salad dressing': 0, 'kitchen utensil': 0, 'baby food': 0, 'sliced cheese': 0, 'bottled beer': 0, 'packaged fruit/vegetables': 0, 'whole milk': 0, 'dessert': 0, 'zwieback': 0, 'potato products': 0, 'specialty chocolate': 0, 'baking powder': 0, 'brown bread': 0, 'pork': 0, 'curd': 0, 'white bread': 0, 'semi-finished bread': 1, 'chicken': 0, 'Instant food products': 0, 'pastry': 0, 'specialty fat': 0}, {'dishes': 0, 'prosecco': 0, 'condensed milk': 0, 'frozen fruits': 0, 'grapes': 0, 'flour': 0, 'waffles': 0, 'oil': 0, 'frozen potato products': 0, 'flower (seeds)': 0, 'dog food': 0, 'rubbing alcohol': 0, 'roll products ': 0, 'misc. beverages': 0, 'baby cosmetics': 0, 'sausage': 0, 'abrasive cleaner': 0, 'honey': 0, 'chocolate': 0, 'butter milk': 0, 'processed cheese': 0, 'preservation products': 0, 'hard cheese': 0, 'pip fruit': 0, 'newspapers': 0, 'shopping bags': 0, 'canned beer': 0, 'cat food': 0, 'frozen chicken': 0, 'light bulbs': 0, 'jam': 0, 'bathroom cleaner': 0, 'kitchen towels': 0, 'nut snack': 0, 'softener': 0, 'hair spray': 0, 'popcorn': 0, 'sugar': 0, 'napkins': 0, 'hamburger meat': 0, 'cooking chocolate': 0, 'vinegar': 0, 'male cosmetics': 0, 'domestic eggs': 0, 'cleaner': 0, 'salty snack': 0, 'meat spreads': 0, 'candles': 0, 'white wine': 0, 'female sanitary products': 0, 'cereals': 0, 'other vegetables': 0, 'cookware ...

# %%
grocery_df = pd.DataFrame(output_list)

# %%
s = "Hello"
for x,y in enumerate(s):
  print(f"index: {x} - value: {y}")
# Out:
# index: 0 - value: H
# index: 1 - value: e
# index: 2 - value: l
# index: 3 - value: l
# index: 4 - value: o
